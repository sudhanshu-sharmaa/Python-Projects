# %%
#1.	Store a message in a variable and print it in:
#o	Uppercase
#o	Lowercase
#o	Title case (first letter capitalized)

message = "python is easy language"
print(message.upper())
print(message.lower())
print(message.title())
# Out:
# PYTHON IS EASY LANGUAGE
# python is easy language
# Python Is Easy Language

# %%
#2.	Store a person’s name in a variable. Print a message such as:
#"Hello Alice, welcome to Python programming!"
name = "Alice"
message = "welcome to Python programming!"
print("hello " + name + " , " + message)
# Out:
# hello Alice , welcome to Python programming!

# %%
###3.	Store a word in a variable and print:
#o	The first character
#o	The last character
#o	The length of the word
word = "shyam"
print("first character",word[0])
print("last character",word[-1])
print("length of the word",len(word))
# Out:
# first character s
# last character m
# length of the word 5

# %%
#4.	Find your favorite quote and print it with quotation marks. Example:
#"Mahatma Gandhi once said, “Be the change that you wish to see in the world.”
quote = "the future belongs to those who believe on beauty of their dreams."
print('"'+quote+'"')
# Out:
# "the future belongs to those who believe on beauty of their dreams."

# %%
#5.	Store two strings in different variables and print them joined with a space in between.
first ="i love food"
second = " i also want to focus on my health"
result= "-".join([first,second])
print(result)
# Out:
# i love food- i also want to focus on my health

# %%
#6.	Store a sentence in a variable and check if it contains the word "Python". Print True or False. - " i love python "
sentence = " i love python "
print("python" in sentence)
# Out:
# True

# %%
#7.	Ask the user to enter their name and print:
#"Hello <name>, how are you today?"
s = input("enter your name -")
print("hello " + s + " , " + "how are you today?")
print(f"Hello {s}, how are you today?")
# Out:
# enter your name - rahul
# hello rahul , how are you today?
# Hello rahul, how are you today?

# %%
#8.	Ask the user to enter their age and print:
#"You are <age> years old."
age = input("enter your age -")
print(f"you are {age},years old")
print("you are " + age +" , " "years old")
# Out:
# enter your age - 15
# you are 15,years old
# you are 15 , years old

# %%
#9.	Ask the user for two numbers and print their:
#o	Sum
#o	Difference
#o	Product
#o	Quotient
first_number = float(input("Enter first number-"))
second_number= float(input("Enter second number-"))
print("sum =",first_number + second_number)
print("Difference =",first_number - second_number)
print("product =",first_number * second_number)
print("Quotient =",first_number / second_number)
# Out:
# Enter first number- 10
# Enter second number- 2
# sum = 12.0
# Difference = 8.0
# product = 20.0
# Quotient = 5.0

# %%
#10.	Ask the user to enter a sentence and print it reversed.
sentence = input("enter your sentence -")
print("Reversed:",sentence[::-1])
# Out:
# enter your sentence - i love food
# Reversed: doof evol i

# %%
#11.	Ask the user for their favorite color and print:
#"Wow! <color> is a beautiful color!"
fav_colour = input("Enter your fav colour -")
print(f"wow! {fav_colour} is a beatiful colour!")
# Out:
# Enter your fav colour - red
# wow! red is a beatiful colour!

# %%
#12.	Ask the user to enter a number and print True if it is greater than 50, otherwise print False.
number = float(input("Enter a number -"))
print(number>50)
# Out:
# Enter a number - 70
# True

# %%
#13.	Ask the user to enter a number and print True if it is even, otherwise print False.
number = float(input("Enter a number -"))
print(number%2==0)
# Out:
# Enter a number - 60
# True

# %%
#14.	Ask the user to enter their age and check if they are eligible to vote (age ≥ 18). Print True or False.
age = float(input("Enter a age -"))
print(age>= 18)
# Out:
# Enter a age - 56
# True

# %%
#15.	Ask the user to enter two numbers and print True if the first number is greater than the second, else print False.
first_number = float(input("Enter first number-"))
second_number= float(input("Enter second number-"))
print(first_number>second_number)
# Out:
# Enter first number- 50
# Enter second number- 60
# False

# %%
#16.	Ask the user to enter a word and check if its length is more than 5 characters. Print True or False.
word = input("Enter a word -")
print(len(word)>5)
# Out:
# Enter a word - himanshu
# True

# %%
#17.	Write a program that asks the user to enter a password.
#Your program should check and print:
 #- True if the password length is at least 8 characters and contains the word "@" or "#".
 #- False otherwise.
password = input("Enter your password: ")
print(len(password) >= 8 and ("@" in password or "#" in password))
# Out:
# Enter your password:  Dipu123456#$
# True
